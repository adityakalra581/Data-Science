# %%
import pandas as pd
import seaborn as sns
# %pylab inline
from sklearn import *
from sklearn.cluster import KMeans
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=pd.read_csv("tripadvisor_review.csv",index_col='User ID')

# %%
data=data.drop(['Unnamed: 11','Unnamed: 12','?'],axis=1)

# %%
data.head()
# Out:
#          Art Galleries  Dance Clubs  Juice Bars  Restaurants  Museums  \
# User ID
# User 1            0.93          1.8        2.29         0.62     0.80
# User 2            1.02          2.2        2.66         0.64     1.42
# User 3            1.22          0.8        0.54         0.53     0.24
# User 4            0.45          1.8        0.29         0.57     0.46
# User 5            0.51          1.2        1.18         0.57     1.54
#
#          Resorts  Parks/Picnic Spots  Beaches  Theaters  Temples
# User ID
# User 1      2.42                3.19     2.79      1.82     2.42
# User 2      3.18                3.21     2.63      1.86     2.32
# User 3      1.54                3.18     2.80      1.31     2.50
# User 4      1.52                3.18     2.96      1.57     2.86
# User 5      2.02                3.18     2.78      1.18     2.54

# %%
# Another way for data.head(10)=data.iloc[:10,:]
data.iloc[1:12,:]
# Out:
#          Art Galleries  Dance Clubs  Juice Bars  Restaurants  Museums  \
# User ID
# User 2            1.02         2.20        2.66         0.64     1.42
# User 3            1.22         0.80        0.54         0.53     0.24
# User 4            0.45         1.80        0.29         0.57     0.46
# User 5            0.51         1.20        1.18         0.57     1.54
# User 6            0.99         1.28        0.72         0.27     0.74
# User 7            0.90         1.36        0.26         0.32     0.86
# User 8            0.74         1.40        0.22         0.41     0.82
# User 9            1.12         1.76        1.04         0.64     0.82
# User 10           0.70         1.36        0.22         0.26     1.50
# User 11           1.47         1.00        0.70         0.75     1.66
# User 12           0.96         2.96        0.29         0.38     0.88
#
#          Resorts  Parks/Picnic Spots  Beaches  Theaters  Temples
# User ID
# ...

# %%
# colormap = plt.cm.RdBu
# plt.figure(figsize=(14,12))
# plt.title('Pearson Correlation of Features', y=1.05, size=15)
# sns.heatmap(train.astype(float).corr(),linewidths=0.1,vmax=1.0, 
#             square=True, cmap=colormap, linecolor='white', annot=True)


colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(data.astype(float).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

# %% [markdown]
# ### DATA ANALYSIS
# - Which Categories are highly rated so that the advertisement are more about that.
# - Finding similar type of users.
# - Finding some correlation about the users and the ratings.

# %%
x=data.mean()
x.sort_values(ascending=False).plot.bar()

# %%
data['Restaurants'].plot(legend=True, figsize=(15,5))

# %%
km=KMeans()
km
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1])

# %%
#data.loc[data['Fare']<=14.454200,'Fare']=0   # (For 0 to 50%)
y=data.mean(axis=1).sort_values()
#ril['2019-01':'2019-06'].Close
h=list['User 979':'User 190']
h
# Out:
# User ID
# User 979    1.213
# User 385    1.305
# User 324    1.341
# User 542    1.383
# User 190    1.389
# dtype: float64

# %%
data[data.index.isin(['User 979','User 385','User 324','User 542','User 190'])].T.plot.bar()
