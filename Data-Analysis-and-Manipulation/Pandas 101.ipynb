# %% [markdown]
# ## First attempt on pandas

# %%
import pandas as pd
sett= pd.read_excel(r'C:\Users\aditya\Desktop\DATA SCIENCE\Free data\SampleData.xlsx')
#data = pd.read_excel(r'C:\Users\aditya\Desktop\IMS DATA SCIENCE\STATISTICS\Exer3.xlsx')
sett
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2018-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2018-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2018-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2018-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2018-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2018-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2018-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2018-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2018-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2018-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2018-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2018-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2018-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
sett.dtypes
# Out:
# OrderDate    datetime64[ns]
# Region               object
# Rep                  object
# Item                 object
# Units                 int64
# Unit Cost           float64
# Total               float64
# dtype: object

# %%
sett.head()        # Shows first five rows
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2018-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2018-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2018-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2018-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2018-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
sett[sett['Units']<90]     # all the units having value more than 90 is not shown.
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 1  2018-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2018-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2018-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2018-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2018-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2018-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 8  2018-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2018-06-08     East     Jones   Binder     60       8.99   539.40
# 11 2018-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2018-07-29     East    Parent   Binder     81      19.99  1619.19
# 13 2018-08-15     East     Jones   Pencil     35       4.99   174.65
# 14 2018-09-01  Central     Smith     Desk      2     125.00   250.00
# 15 2018-09-18     East     Jones  Pen Set     16      15.99   255.84
# ...

# %%
sett.tail()     # shows last five rows
sett.shape
# Out:
# (43, 7)

# %%
data=sett.tail()      # assignong last five rows to another variable.

# %%
data
# Out:
#     OrderDate   Region       Rep    Item  Units  Unit Cost    Total
# 38 2019-10-14     West  Thompson  Binder     57      19.99  1139.43
# 39 2019-10-31  Central   Andrews  Pencil     14       1.29    18.06
# 40 2019-11-17  Central   Jardine  Binder     11       4.99    54.89
# 41 2019-12-04  Central   Jardine  Binder     94      19.99  1879.06
# 42 2019-12-21  Central   Andrews  Binder     28       4.99   139.72

# %%
data.shape
# Out:
# (5, 7)

# %% [markdown]
# ## Slicing The DATA

# %%
data[data['Units']>20]
# Out:
#     OrderDate   Region       Rep    Item  Units  Unit Cost    Total
# 38 2019-10-14     West  Thompson  Binder     57      19.99  1139.43
# 41 2019-12-04  Central   Jardine  Binder     94      19.99  1879.06
# 42 2019-12-21  Central   Andrews  Binder     28       4.99   139.72

# %% [markdown]
# ## Aggregating methods

# %%
sett.mean()                    # provide the mean of each column
# Out:
# Units         49.325581
# Unit Cost     20.308605
# Total        456.462326
# dtype: float64

# %%
sett.sum(axis=1)       # this gives sum of three numerical columns for each row
# sett.sum(axis=1).head()   # use .head in front of any command for giving desired results 
                            # only for five rows(top)
# Out:
# 0      286.04
# 1     1069.49
# 2      220.63
# 3      586.72
# 4      226.43
# 5      364.39
# 6      226.24
# 7      544.09
# 8       97.67
# 9      608.39
# 10     544.09
# 11      88.70
# 12    1720.18
# 13     214.64
# 14     377.00
# 15     287.83
# 16     288.71
# 17     648.35
# 18     334.84
# 19     580.03
# 20     154.72
# 21    1273.25
# 22     468.53
# 23    1407.00
# 24      28.95
# 25     166.92
# 26     304.49
# 27     199.33
# 28     580.03
# 29     122.66
# 30     808.19
# 31     755.00
# 32     376.37
# 33     754.44
# 34    1071.85
# 35    1103.00
# 36      17.32
# 37     229.23
# 38    1216.42
# 39      33.35
# 40      70.88
# 41    1993.05
# 42     172.71
# dtype: float64

# %% [markdown]
# ## A column for specific value of another column.

# %%
# data.loc[data['column name']==some value,['column1','col2']] 
# here all the values of total is shown where region is "East"
sett.loc[sett['Region']=='East',['Total']]

# %%
type(sett)        ## order= package.subpackage.module.type
                   ## here DataFrame is the type.
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## DATAFRAME & SERIES
# ### Dataframe = Index + Columns + Data
# ### Series = a single column selected from dataframe. It is basically one dimensional data.
# ##### A series only contains index and data for the specified column. Also head() and tail() work same for series.

# %% [markdown]
# ## Selecting a column from dataframe - A Series.

# %%
y=sett['Region']  # this will provide all the values of 'Region' column.
y
# Out:
# 0        East
# 1     Central
# 2     Central
# 3     Central
# 4        West
# 5        East
# 6     Central
# 7     Central
# 8        West
# 9        East
# 10    Central
# 11       East
# 12       East
# 13       East
# 14    Central
# 15       East
# 16    Central
# 17       East
# 18       East
# 19    Central
# 20    Central
# 21       East
# 22    Central
# 23    Central
# 24       East
# 25       West
# 26    Central
# 27    Central
# 28       East
# 29    Central
# 30    Central
# 31    Central
# 32       East
# 33    Central
# 34    Central
# 35       West
# 36    Central
# 37       West
# 38       West
# 39    Central
# 40    Central
# 41    Central
# 42    Central
# Name: Region, dtype: object

# %%
type(y)          # Clearly y is a series.
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## .pct_change()           ( percentage change )
#
# Refer this link for more: https://www.youtube.com/watch?v=MSXGbXJiTt4

# %%
sett.head(10)
# Out:
#    OrderDate   Region       Rep    Item  Units  Unit Cost   Total
# 0 2018-01-06     East     Jones  Pencil     95       1.99  189.05
# 1 2018-01-23  Central    Kivell  Binder     50      19.99  999.50
# 2 2018-02-09  Central   Jardine  Pencil     36       4.99  179.64
# 3 2018-02-26  Central      Gill     Pen     27      19.99  539.73
# 4 2018-03-15     West   Sorvino  Pencil     56       2.99  167.44
# 5 2018-04-01     East     Jones  Binder     60       4.99  299.40
# 6 2018-04-18  Central   Andrews  Pencil     75       1.99  149.25
# 7 2018-05-05  Central   Jardine  Pencil     90       4.99  449.10
# 8 2018-05-22     West  Thompson  Pencil     32       1.99   63.68
# 9 2018-06-08     East     Jones  Binder     60       8.99  539.40

# %%
sett.dtypes       #pct_change()= currentvalue-previous value
# Out:
# OrderDate    datetime64[ns]
# Region               object
# Rep                  object
# Item                 object
# Units                 int64
# Unit Cost           float64
# Total               float64
# dtype: object

# %%
y=sett['Total']
                              # it is applied only on float and integer values.

# %%
y.pct_change()
# Out:
# 0           NaN
# 1      4.286961
# 2     -0.820270
# 3      2.004509
# 4     -0.689771
# 5      0.788103
# 6     -0.501503
# 7      2.009045
# 8     -0.858205
# 9      7.470477
# 10    -0.167408
# 11    -0.871499
# 12    27.057356
# 13    -0.892137
# 14     0.431434
# 15     0.023360
# 16    -0.016104
# 17     1.285714
# 18    -0.478848
# 19     0.597599
# 20    -0.819577
# 21    12.690385
# 22    -0.650508
# 23     2.155680
# 24    -0.984705
# 25     6.010521
# 26     0.783034
# 27    -0.473587
# 28     2.647328
# 29    -0.857277
# 30     9.519234
# 31    -0.130979
# 32    -0.504992
# 33     1.220409
# 34     0.464299
# 35    -0.179839
# 36    -0.989055
# 37    15.748616
# 38     6.533920
# 39    -0.984150
# 40     2.039313
# 41    33.233194
# 42    -0.925644
# Name: Total, dtype: float64

# %%
y.pct_change(periods=2)          ## period=2 means value at 0 is subtracted by value at 2 and so on
                                 ## use axis= 1 for row wise subtraction
# Out:
# 0            NaN
# 1            NaN
# 2      -0.049775
# 3      -0.460000
# 4      -0.067914
# 5      -0.445278
# 6      -0.108636
# 7       0.500000
# 8      -0.573333
# 9       0.201069
# 10      6.052450
# 11     -0.893011
# 12      2.605411
# 13      2.026339
# 14     -0.845602
# 15      0.464873
# 16      0.006880
# 17      1.248906
# 18      0.191205
# 19     -0.167408
# 20     -0.711756
# 21      1.470065
# 22      3.784681
# 23      0.102885
# 24     -0.951734
# 25     -0.892774
# 26     11.500000
# 27     -0.061388
# 28      0.920000
# 29     -0.479443
# 30      0.501336
# 31      8.141436
# 32     -0.569828
# 33      0.099120
# 34      2.251341
# 35      0.200961
# 36     -0.991023
# 37     -0.816679
# 38    125.182724
# 39     -0.880587
# 40     -0.951827
# 41    103.045404
# 42      1.545455
# Name: Total, dtype: float64
