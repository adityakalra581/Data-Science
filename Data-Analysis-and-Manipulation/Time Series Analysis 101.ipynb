# %%
import pandas as pd

# %%
sen=pd.read_csv(r'C:\Users\aditya\Desktop\DATA SCIENCE\Free data\TCS.NSE.csv')
sen.head(3)
# Out:
#        Date         Open         High          Low        Close   Adj Close  \
# 0  1/1/2014  1090.050049  1192.400024  1073.619995  1120.530029  944.198914
# 1  2/1/2014  1111.000000  1140.000000  1042.550049  1137.880005  962.242004
# 2  3/1/2014  1135.900024  1149.500000  1005.700012  1066.569946  901.938904
#
#      Volume
# 0  66137366
# 1  45670390
# 2  64102864

# %%
sen.dtypes # We have to convert month into date_time to exploit better features.
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# ## Conversion of  column in date_time using parse_dates=['column name']

# %%
sen=pd.read_csv(r'C:\Users\aditya\Desktop\DATA SCIENCE\Free data\TCS.NSE.csv',parse_dates=['Date'])
sen.head(3)
# Out:
#         Date         Open         High          Low        Close   Adj Close  \
# 0 2014-01-01  1090.050049  1192.400024  1073.619995  1120.530029  944.198914
# 1 2014-02-01  1111.000000  1140.000000  1042.550049  1137.880005  962.242004
# 2 2014-03-01  1135.900024  1149.500000  1005.700012  1066.569946  901.938904
#
#      Volume
# 0  66137366
# 1  45670390
# 2  64102864

# %%
sen.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
type(sen.Date[0])   # ANother way to check the data type.
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ## Making the date column the index of the data.

# %%
sen=pd.read_csv(r'C:\Users\aditya\Desktop\DATA SCIENCE\Free data\TCS.NSE.csv',parse_dates=['Date'],index_col=['Date'])
sen.head(3)
# Out:
#                    Open         High          Low        Close   Adj Close  \
# Date
# 2014-01-01  1090.050049  1192.400024  1073.619995  1120.530029  944.198914
# 2014-02-01  1111.000000  1140.000000  1042.550049  1137.880005  962.242004
# 2014-03-01  1135.900024  1149.500000  1005.700012  1066.569946  901.938904
#
#               Volume
# Date
# 2014-01-01  66137366
# 2014-02-01  45670390
# 2014-03-01  64102864

# %%
sen.index
# Out:
# DatetimeIndex(['2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01',
#                '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01',
#                '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01',
#                '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#                '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#                '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#                '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#                '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01',
#                '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01',
#                '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01',
#                '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01',
#                '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#                '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
# ...

# %% [markdown]
# ### Retreiving data on the basis of dates only

# %%
sen['2017']             # will provide the data of 2017 only
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-01-01  1183.300049  1194.969971  1100.030029  1114.900024  1040.747070
# 2017-02-01  1110.000000  1277.500000  1076.500000  1233.119995  1157.689453
# 2017-03-01  1239.949951  1293.569946  1203.000000  1215.900024  1141.522827
# 2017-04-01  1217.500000  1224.500000  1126.400024  1136.569946  1067.045532
# 2017-05-01  1136.569946  1318.780029  1134.250000  1273.300049  1195.411987
# 2017-06-01  1265.000000  1354.469971  1161.550049  1181.180054  1108.926758
# 2017-07-01  1178.699951  1292.400024  1162.750000  1245.900024  1196.138306
# 2017-08-01  1250.000000  1274.949951  1230.050049  1248.180054  1205.099487
# 2017-09-01  1240.000000  1270.500000  1210.750000  1217.969971  1175.932129
# 2017-10-01  1217.969971  1320.000000  1212.199951  1312.000000  1266.716797
# 2017-11-01  1312.000000  1388.699951  1289.430054  1318.500000  1279.942261
# ...

# %%
#  [yyyy-mm-dd] = format

sen['2017-01']        # Provide the data of jan 2017
# Out:
#                    Open         High          Low        Close   Adj Close  \
# Date
# 2017-01-01  1183.300049  1194.969971  1100.030029  1114.900024  1040.74707
#
#               Volume
# Date
# 2017-01-01  59700074

# %%
# Closing price for jan 2017

sen['2017-01'].Close
# Out:
# Date
# 2017-09-01    1217.969971
# Name: Close, dtype: float64

# %%
# obtaining 2017 closing price mean

sen['2017'].Close.mean()                   # instead of mean we can find sum as well.
# Out:
# 1237.3433430833334

# %% [markdown]
# ### Getting data in a range

# %%
## dataframe['lower range':'Upper range']
sen['2015':'2016']                        # the data b/w upper and lower range
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-01-01  1283.500000  1299.949951  1203.719971  1241.030029  1078.279053
# 2015-02-01  1241.000000  1365.000000  1216.500000  1331.180054  1161.244873
# 2015-03-01  1339.849976  1406.050049  1250.500000  1276.969971  1113.955078
# 2015-04-01  1279.000000  1356.949951  1200.500000  1231.849976  1074.595215
# 2015-05-01  1231.849976  1324.300049  1226.849976  1305.150024  1138.537842
# 2015-06-01  1304.719971  1323.550049  1238.400024  1275.469971  1112.646973
# 2015-07-01  1281.949951  1323.449951  1227.500000  1255.380005  1115.673584
# 2015-08-01  1251.699951  1376.430054  1243.000000  1282.030029  1144.266357
# 2015-09-01  1278.000000  1321.849976  1245.000000  1294.030029  1154.977051
# 2015-10-01  1299.500000  1385.000000  1227.930054  1247.599976  1113.536255
# 2015-11-01  1250.000000  1273.900024  1166.250000  1186.780029  1068.529053
# ...

# %%
# %matplotlib inline
sen.Close.plot(figsize=(10,4))
